# %% [markdown]
# ### Set creation

# %%
myset = {"apple", "banana", "cherry"}
print(myset)
# Out:
# {'apple', 'banana', 'cherry'}

# %%
# Length of set
print(len(myset))
# Out:
# 3

# %% [markdown]
# ### Duplicates Not Allowed

# %%
myset = {"apple", "banana", "cherry","apple"}
print(myset)
# Out:
# {'apple', 'banana', 'cherry'}

# %% [markdown]
# ### True and 1 is considered the same value and False and 0 is considered the same value

# %%
thisset = {"apple", "banana", "cherry", True, 1, 2}

print(thisset)
# Out:
# {True, 2, 'banana', 'cherry', 'apple'}

# %%
thisset = {"apple", "banana", "cherry", False, 1, 2,0}

print(thisset)
# Out:
# {False, 1, 2, 'banana', 'cherry', 'apple'}

# %% [markdown]
# ### Access Items

# %%
thisset = {"apple", "banana", "cherry"}
for i in thisset:
    print(i)
# Out:
# apple
# banana
# cherry

# %%
thisset = {"apple", "banana", "cherry"}
if "banana" in thisset:
    print("Yes,banana in this set")
else:
    print("No, banana not in this set")
# Out:
# Yes,banana in this set

# %%
thisset = {"apple", "banana", "cherry"}
print("banana" in thisset)
# Out:
# True

# %%
thisset = {"apple", "banana", "cherry"}
print("banana" not in thisset)
# Out:
# False

# %% [markdown]
# ### Add set items

# %%
thisset = {"apple", "banana", "cherry"}
thisset.add('orange')
print(thisset)
# Out:
# {'orange', 'apple', 'banana', 'cherry'}

# %%
thisset = {"apple", "banana", "cherry"}
tropical = {"pineapple", "mango", "papaya"}
thisset.update(tropical)
print(thisset)
# Out:
# {'banana', 'cherry', 'pineapple', 'papaya', 'apple', 'mango'}

# %%
thisset = {"apple", "banana", "cherry"}
mylist = ["kiwi", "orange"]

thisset.update(mylist)

print(thisset)
# Out:
# {'banana', 'cherry', 'apple', 'kiwi', 'orange'}

# %% [markdown]
# ### Remove Set Items

# %%
thisset = {"apple", "banana", "cherry"}
thisset.remove("banana") # if the specific item not in this list then remove item gives an error
print(thisset)
# Out:
# {'apple', 'cherry'}

# %%
thisset = {"apple", "banana", "cherry"}
thisset.discard("banana") # discard item does not gives error if specific value not in the list
print(thisset)
# Out:
# {'apple', 'cherry'}

# %%
thisset = {"apple", "banana", "cherry"}
thisset.pop() # can say which index value will be remove
print(thisset)
# Out:
# {'banana', 'cherry'}

# %% [markdown]
# ### Loop Sets

# %%
thisset = {"apple", "banana", "cherry"}
for i in thisset:
    print(i)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# ### Join Sets

# %%
# The union() method returns a new set with all items from both sets.
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}
set3 = set1.union(set2)
print(set3)
# Out:
# {'b', 1, 2, 3, 'c', 'a'}

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}
set3 = set1|set2
print(set3)
# Out:
# {'b', 1, 2, 3, 'c', 'a'}

# %% [markdown]
# ### Join Multiple Sets

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}
set3 = {"John", "Elena"}
set4 = {"apple", "bananas", "cherry"}

set5 = set1.union(set2,set3,set4)
print(set5)
# Out:
# {1, 2, 3, 'Elena', 'cherry', 'apple', 'b', 'John', 'c', 'a', 'bananas'}

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}
set3 = {"John", "Elena"}
set4 = {"apple", "bananas", "cherry"}
set5 = set1|set2|set3|set4
print(set5)
# Out:
# {1, 2, 3, 'Elena', 'cherry', 'apple', 'b', 'John', 'c', 'a', 'bananas'}

# %% [markdown]
# ### Join a Set and a Tuple

# %%
x = {"a", "b", "c"}
y = (1, 2, 3)
z = x.union(y)
print(z)
# Out:
# {1, 2, 3, 'b', 'c', 'a'}

# %% [markdown]
# ### Update()
# #### The update() changes the original set

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}
set1.update(set2)
print(set1)
# Out:
# {'b', 1, 2, 3, 'c', 'a'}

# %% [markdown]
# ### Intersection
# #### Keep ONLY the duplicates
# ## Do not change the original set

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}
set3 = set1.intersection(set2)
print(set3)
# Out:
# {'apple'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1 & set2
print(set3)
# Out:
# {'apple'}

# %% [markdown]
# ### Insersection_update change the original set

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set1.intersection_update(set2)

print(set1)
# Out:
# {'apple'}

# %%
set1 = {"apple", 1,  "banana", 0, "cherry"}
set2 = {False, "google", 1, "apple", 2, True}
set3 = set1.intersection(set2)

print(set3)
# Out:
# {False, 1, 'apple'}

# %% [markdown]
# ### Difference
# #### The difference() method will return a new set that will contain only the items from the first set that are not present in the other set.

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1.difference(set2)

print(set3)
# Out:
# {'banana', 'cherry'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1-set2

print(set3)
# Out:
# {'banana', 'cherry'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}
set1.difference_update(set2)

print(set1)
# Out:
# {'banana', 'cherry'}

# %% [markdown]
# ### Symmetric Differences
# #### The symmetric_difference() method will keep only the elements that are NOT present in both sets.

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1.symmetric_difference(set2)
print(set3)
# Out:
# {'banana', 'cherry', 'google', 'microsoft'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1 ^ set2
print(set3)
# Out:
# {'banana', 'cherry', 'google', 'microsoft'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set1.symmetric_difference_update(set2)

print(set1)
# Out:
# {'banana', 'cherry', 'google', 'microsoft'}

# %% [markdown]
# ## frozenset

# %%
x = frozenset({"apple", "banana", "cherry"})
print(x)
print(type(x))
# Out:
# frozenset({'apple', 'banana', 'cherry'})
# <class 'frozenset'>

# %% [markdown]
# # Practice Problems

# %% [markdown]
# 1. Perform Basic Set Operations
# - Create a Set: Create a set named fruits containing “apple”, “banana”, “mango”, and “orange”.
# - Add Element: Add “grape” to the fruits set.
# - Remove Element: Remove “banana” from the fruits set.
# - Discard Element: Try to discard “mango” from the fruits set.
# - Expected Output:
#
# 1. After creating the set: {'apple', 'orange', 'mango', 'banana'}
# 2. After adding 'grape': {'orange', 'banana', 'grape', 'apple', 'mango'}
# 3. After removing 'banana': {'orange', 'grape', 'apple', 'mango'}
# 4. After discarding 'mango': {'orange', 'grape', 'apple'}

# %%
fruits = {"apple", "banana", "mango", "orange"}
print(f"After creating set: {fruits}")
fruits.add("grape")
print(f"After adding 'grape':{fruits}")
fruits.remove("banana")
print(f"After removing 'banana': {fruits}")
fruits.discard("mango")
print(f"After discarding 'mango':{fruits}")
# Out:
# After creating set: {'orange', 'apple', 'banana', 'mango'}
# After adding 'grape':{'banana', 'apple', 'grape', 'orange', 'mango'}
# After removing 'banana': {'apple', 'grape', 'orange', 'mango'}
# After discarding 'mango':{'apple', 'grape', 'orange'}

# %% [markdown]
# 2. Union of Sets
# - Find the union of set1 and set2. Write a Python program to return a new set with unique items from both sets by removing duplicates.
#
# Given:
#
# set1 = {10, 20, 30, 40, 50}
#
# set2 = {30, 40, 50, 60, 70}
#
# Expected Output:
#
# {70, 40, 10, 50, 20, 60, 30}

# %%
set1 = {10, 20, 30, 40, 50}
set2 = {30, 40, 50, 60, 70}
set3 = set1.union(set2)
print(set3)
# Out:
# {70, 40, 10, 50, 20, 60, 30}

# %% [markdown]
# 3. Intersection of Sets
# - Find the intersection of set1 and set2. Write a code to return a new set containing only the elements that are common to both set1 and set2
#
# Given:
#
# set1 = {10, 20, 30, 40, 50}
#
# set2 = {30, 40, 50, 60, 70}
#
# Expected Output:
#
# {40, 50, 30}

# %%
set1 = {10, 20, 30, 40, 50}
set2 = {30, 40, 50, 60, 70}
set3 = set1.intersection(set2)
print(set3)
# Out:
# {40, 50, 30}

# %% [markdown]
# 4. Difference of Sets
# - Find the difference (set1 - set2). Write a code to returns a new set containing elements that are present in set1 but not in set2.
#
# Given:
#
# set1 = {10, 20, 30, 40, 50}
#
# set2 = {30, 40, 50, 60, 70}
#
# Expected Output:
#
# {10, 20}

# %%
set1 = {10, 20, 30, 40, 50}
set2 = {30, 40, 50, 60, 70}
set3 = set1.difference(set2)
print(set3)
# Out:
# {10, 20}

# %% [markdown]
# 5. Symmetric Difference
# - Find the symmetric difference of set1 and set2. Write a code to returns a new set containing elements that are unique to either set1 or set2, but not in both. It’s like finding the union and then removing the intersection.
#
# Given:
#
# set1 = {10, 20, 30, 40, 50}
#
# set2 = {30, 40, 50, 60, 70}
#
# Expected Output:
#
# {20, 70, 10, 60}

# %%
set1 = {10, 20, 30, 40, 50}
set2 = {30, 40, 50, 60, 70}
set3 = set1.symmetric_difference(set2)
print(set3)
# Out:
# {20, 70, 10, 60}

# %% [markdown]
# 6. Add a list of Elements to a Set <br>
# Given a Python list, write a program to add all of its elements into a given set.
#
# Given:
#
# sample_set = {"Yellow", "Orange", "Black"}<br>
# sample_list = ["Blue", "Green", "Red"]<br>
# Expected output:
#
# Note: Set is unordered.
#
# {'Green', 'Yellow', 'Black', 'Orange', 'Red', 'Blue'}

# %%
sample_set = {"Yellow", "Orange", "Black"}
sample_list = ["Blue", "Green", "Red"]
sample_set.update(sample_list)
print(sample_set)
# Out:
# {'Blue', 'Green', 'Orange', 'Yellow', 'Black', 'Red'}

# %% [markdown]
# 7. Set Difference Update<br>
# Given two Python sets, write a program to update the first set with only the items that are unique to it (i.e., not present in the second set).
#
# Given:
#
# set1 = {10, 20, 30}<br>
# set2 = {20, 40, 50}<br>
# Expected output:
#
# set1 {10, 30}

# %%
set1 = {10, 20, 30}
set2 = {20, 40, 50}
set1.difference_update(set2)
print(set1)
# Out:
# {10, 30}
