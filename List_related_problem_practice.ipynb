# %% [markdown]
# 1. Write a code to create a new list using odd-indexed elements from the first list and even-indexed elements from the second
#
# - Given two lists, l1 and l2, write a program to create a third list l3 by picking an odd-index element from the list l1 and even index elements from the list l2.
#
# - l1 = [3, 6, 9, 12, 15, 18, 21]
# - l2 = [4, 8, 12, 16, 20, 24, 28]
#
#
# Expected Output:
#
# Element at odd-index positions from list one
# [6, 12, 18]
#
# Element at even-index positions from list two
# [4, 12, 20, 28]
#
# Printing Final third list
# [6, 12, 18, 4, 12, 20, 28]

# %%
l1 = [3, 6, 9, 12, 15, 18, 21]

l2 = [4, 8, 12, 16, 20, 24, 28]

odd_indexed = l1[1::2]
even_indexed = l2[::2]
l3 = []
l3.extend(odd_indexed)
l3.extend(even_indexed)
print(l3)
# Out:
# [6, 12, 18, 4, 12, 20, 28]

# %% [markdown]
# Write a program to remove the item present at index 4 and add it to the 2nd position and at the end of the list.
#
# Given:
#
# sample_list = [34, 54, 67, 89, 11, 43, 94]
#
# Expected Output:
#
# - List After removing element at index 4  [34, 54, 67, 89, 43, 94]
# - List after Adding element at index 2  [34, 54, 11, 67, 89, 43, 94]
# - List after Adding element at last  [34, 54, 11, 67, 89, 43, 94, 11]

# %%
sample_list = [34, 54, 67, 89, 11, 43, 94]

print("Original list ", sample_list)
element = sample_list.pop(4)
print("List After removing element at index 4 ", sample_list)

sample_list.insert(2, element)
print("List after Adding element at index 2 ", sample_list)

sample_list.append(element)
print("List after Adding element at last ", sample_list)
# Out:
# Original list  [34, 54, 67, 89, 11, 43, 94]
# List After removing element at index 4  [34, 54, 67, 89, 43, 94]
# List after Adding element at index 2  [34, 54, 11, 67, 89, 43, 94]
# List after Adding element at last  [34, 54, 11, 67, 89, 43, 94, 11]

# %% [markdown]
# Slice list into 3 equal chunks and reverse each chunk
# - Given:
#
# - sample_list = [11, 45, 8, 23, 14, 12, 78, 45, 89]
# - Expected Outcome:
#
# - Chunk  1 [11, 45, 8]
# - After reversing it  [8, 45, 11]
# - Chunk  2 [23, 14, 12]
# - After reversing it  [12, 14, 23]
# - Chunk  3 [78, 45, 89]
# - After reversing it  [89, 45, 78]

# %%
sample_list = [11, 45, 8, 23, 14, 12, 78, 45, 89]
length = len(sample_list)
chunk_size = int(length/3)
start = 0
end = chunk_size
for i in range(3):
    indexes = slice(start,end)
    list_chunk = sample_list[indexes]
    print("Chunk",i+1,list_chunk)
    print("After reversing it",list(reversed(list_chunk)))
    start = end
    end+=chunk_size
# Out:
# Chunk 1 [11, 45, 8]
# After reversing it [8, 45, 11]
# Chunk 2 [23, 14, 12]
# After reversing it [12, 14, 23]
# Chunk 3 [78, 45, 89]
# After reversing it [89, 45, 78]

# %% [markdown]
# 4. Write a program to iterate a given list and count the occurrence of each element and create a dictionary to show the count of each element
#
# sample_list = [11, 45, 8, 11, 23, 45, 23, 45, 89]
# - Expected Output:
#
# Printing count of each item   {11: 2, 45: 3, 8: 1, 23: 2, 89: 1}

# %%
from collections import Counter
sample_list = [11, 45, 8, 11, 23, 45, 23, 45, 89]
char_dict = Counter(sample_list)

print("Printing count of each item:", dict(char_dict))
# Out:
# Printing count of each item: {11: 2, 45: 3, 8: 1, 23: 2, 89: 1}

# %%
sample_list = [11, 45, 8, 11, 23, 45, 23, 45, 89]
new_dict = dict()
for char in sample_list:
    count = sample_list.count(char)
    new_dict[char] = count
print("Printing count of each item:",new_dict)
# Out:
# Printing count of each item: {11: 2, 45: 3, 8: 1, 23: 2, 89: 1}

# %% [markdown]
# my_list = [10, 20, 30, 40, 50]
#
# Perform following operations on given list
#
# - Access Elements: Print the third element.
# - List Length: Print the number of elements in the list
# - Check if Empty: Write a code to check is list empty.
# -
# Expected Output:
#
# Initial list: [10, 20, 30, 40, 50]
#
# - Third item:  30
# - Length of the list: 5
# - list is not empty

# %%
my_list = [10, 20, 30, 40, 50]
third_item = my_list[2]
length_list = len(my_list)
print("Third item :",third_item)
print("Length of the list: ",length_list)
if length_list == 0:
    print("List is empty")
else:
    print("List is not empty")
# Out:
# Third item : 30
# Length of the list:  5
# List is not empty

# %% [markdown]
# my_list = [10, 20, 30, 40, 50]
# - Perform following list manipulation operations on given list
#
# 1. Change Element: Change the second element of a list to 200 and print the updated list.
# 2. Append Element: Add 600 o the end of a list and print the new list.
# 3. Insert Element: Insert 300 at the third position (index 2) of a list and print the result.
# 4. Remove Element (by value): Remove 600 from the list and print the list.
# 5. Remove Element (by index): Remove the element at index 0 from the list print the list.

# %%
my_list = [10, 20, 30, 40, 50]
my_list[1] = 200
print(f"After changing second element 200 : {my_list}")
my_list.append(600)
print(f"After appending 600 the list is : {my_list}")
my_list.insert(2,300)
print(f"After inserting 300: {my_list}")
my_list.remove(600)
print(f"After removing 600: {my_list}")
my_list.pop(0)
print(f"After removing the 0 index element: {my_list}")
# Out:
# After changing second element 200 : [10, 200, 30, 40, 50]
# After appending 600 the list is : [10, 200, 30, 40, 50, 600]
# After inserting 300: [10, 200, 300, 30, 40, 50, 600]
# After removing 600: [10, 200, 300, 30, 40, 50]
# After removing the 0 index element: [200, 300, 30, 40, 50]

# %% [markdown]
# Calculate and print the sum and average of all numbers in a list.
#
# Given:
#
# 1. my_list = [10, 20, 30, 40, 50]
# - Expected Output:
# - Sum: 150
# - Average: 30.0

# %%
my_list = [10, 20, 30, 40, 50]
sum = 0
for i in my_list:
    sum+=i
avg = sum/len(my_list)
print(f"Sum: {sum}")
print(f"Average: {avg}")
# Out:
# Sum: 150
# Average: 30.0

# %% [markdown]
# Reverse a list
#
# Given:
#
# 1. list1 = [100, 200, 300, 400, 500]
# - Expected output:
#
# [500, 400, 300, 200, 100]

# %%
list1 = [100, 200, 300, 400, 500]
rev_list = list1[::-1]
print(rev_list)
# Out:
# [500, 400, 300, 200, 100]

# %%
list1 = [100, 200, 300, 400, 500]
list1.reverse()
print(list1)
# Out:
# [500, 400, 300, 200, 100]

# %% [markdown]
# Turn every item of a list into its square
# - Given a list of numbers. write a program to turn every item of a list into its square.
#
# Given:
#
# 1. numbers = [1, 2, 3, 4, 5, 6, 7]
# - Expected output:
#
# [1, 4, 9, 16, 25, 36, 49]

# %%
numbers = [1, 2, 3, 4, 5, 6, 7]
squre_list = []
for i in numbers: 
    squre_list.append(i**2)
print(squre_list)
# Out:
# [1, 4, 9, 16, 25, 36, 49]

# %% [markdown]
# Find Maximum and Minimum
# - Find and print the largest and smallest number in a list [8, 2, 15, 1, 9].
#
# Given:
#
# 1. data = [8, 2, 15, 1, 9]
# - Expected Output:
#
# - Largest number: 15
# - Smallest number: 1

# %%
data = [8, 2, 15, 1, 9]
data.sort()
largest_number = data[-1]
smallest_number = data[0]
print(f"Largest number: {largest_number}")
print(f"Smallest number: {smallest_number}")
# Out:
# Largest number: 15
# Smallest number: 1

# %% [markdown]
# * Count Occurrences
# * Count and print how many times 'Football' appears in list.
#
# Given:
#
# sports = ['Cricket', 'Football', 'Hockey', 'Football', 'Tennis'].

# %%
sports = ['Cricket', 'Football', 'Hockey', 'Football', 'Tennis']

count_word = 'Football'
football_count = sports.count(count_word)
print(football_count)
# Out:
# 2

# %% [markdown]
# Sort a list of numbers
# - Sort a given list of numbers in ascending order and print it.
#
# Given: numbers = [5, 2, 8, 1, 9]
#
# Expected Output:
#
# - Original list: [5, 2, 8, 1, 9]
# - Sorted list: [1, 2, 5, 8, 9]

# %%
numbers = [5, 2, 8, 1, 9]
print(f"Original list: {numbers}")
numbers.sort()
print(f"Sorted list: {numbers}")
# Out:
# Original list: [5, 2, 8, 1, 9]
# Sorted list: [1, 2, 5, 8, 9]

# %% [markdown]
# 1. Create a copy of a list
# -  Create a copy of a list [10, 20, 30] and modify the copy.
# -  Print both the original and the copied list to demonstrate they are independent.

# %%
list1 =  [10, 20, 30] 
copy_list = list1[:]
print(f"Original list: {list1}")
print(f"Copy list: {copy_list}")
# Out:
# Original list: [10, 20, 30]
# Copy list: [10, 20, 30]

# %% [markdown]
# 1. Combine two lists
# - Combine given two lists into a single list and print it.
#
# Given:
#
# - list_a = [1, 2]
# - list_b = [3, 4]
# - Expected Output:
#
# [1, 2, 3, 4]

# %%
list_a = [1, 2]
list_b = [3, 4]
list_a.extend(list_b)
print(list_a)
# Out:
# [1, 2, 3, 4]

# %%
list_a = [1, 2]
list_b = [3, 4]
list_c = list_a + list_b
print(list_c)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# - Remove empty strings from the list of strings
# - list1 = ["Mike", "", "Emma", "Kelly", "", "Brad"]
# - Expected output:
#
# ["Mike", "Emma", "Kelly", "Brad"]

# %%
list1 = ["Mike", "", "Emma", "Kelly", "", "Brad"]
not_empty = []
empty_string = [None, ""]
for i in list1:
    if i not in empty_string:
        not_empty.append(i)
print(not_empty)
# Out:
# ['Mike', 'Emma', 'Kelly', 'Brad']

# %%
list1 = ["Mike", "", "Emma", "Kelly", "", "Brad"]
not_empty1 = list(filter(None,list1))
print(not_empty1)
# Out:
# ['Mike', 'Emma', 'Kelly', 'Brad']

# %% [markdown]
# - Remove Duplicates from list
# - Write a function that takes a list with duplicate elements and returns a new list with only unique elements.
#
# Given: list_with_duplicates = [1, 2, 2, 3, 1, 4, 5, 4]
#
# Expected Output:
#
# [1, 2, 3, 4, 5]

# %%
list_with_duplicates = [1, 2, 2, 3, 1, 4, 5, 4]
list_without_duplicates = set(list_with_duplicates)
print(list(list_without_duplicates))
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# 13. Given a Python list, write a program to remove all occurrences of item 20.
#
# Given:
#
# list1 = [5, 20, 15, 20, 25, 50, 20]
# - Expected output:
#
# [5, 15, 25, 50]

# %%
list1 = [5, 20, 15, 20, 25, 50, 20]
remove_item = 20
new_list = []
for i in list1:
    if i != remove_item:
        new_list.append(i)
print(new_list)
# Out:
# [5, 15, 25, 50]

# %% [markdown]
# 14. Use list comprehension to create a new list containing only the numbers from a given list.
#
# Given:
#
# my_list = [1, 2, 3, 'Jessa', 4, 5, 'Kelly', 'Jhon', 6]
# - Expected Output:
#
# [1, 2, 3, 4, 5, 6]

# %%
my_list = [1, 2, 3, 'Jessa', 4, 5, 'Kelly', 'Jhon', 6]
new_list = [dig for dig in my_list if isinstance(dig,(int,float))]
print(new_list)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# 15. Given a nested list, print the element '55'
# - nested_list = [[10, 20, 30], [44, 55, 66], [77, 87, 99]]

# %%
nested_list = [[10, 20, 30], [44, 55, 66], [77, 87, 99]]
find_55 = nested_list[1][1]
print(find_55)
# Out:
# 55

# %% [markdown]
# 16. Write a function to flatten a list of lists into a single, non-nested list. (e.g., [[1, 2], [3, 4]] becomes [1, 2, 3, 4]).
#
# Given:
#
# list_of_lists = [[1, 2], [3, 4], [5, 6, 7]]
# - Expected Output:
#
# [1, 2, 3, 4, 5, 6, 7]

# %%
list_of_lists = [[1, 2], [3, 4], [5, 6, 7]]
new_list = []
for i in list_of_lists:
    for j in i:
        new_list.append(j)
print(new_list)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# 17. Write a program to add two lists index-wise. Create a new list that contains the 0th index item from both the list, then the 1st index item, and so on till the last element. any leftover items will get added at the end of the new list.
#
# Given:
#
# list1 = ["M", "na", "i", "Ke"]
#
# list2 = ["y", "me", "s", "lly"]

# %%
list1 = ["M", "na", "i", "Ke"]

list2 = ["y", "me", "s", "lly"]
list3 = [i+j for i,j in zip(list1,list2)]
print(list3)
# Out:
# ['My', 'name', 'is', 'Kelly']

# %% [markdown]
# 18. Concatenate two lists in the following order
#
# list1 = ["Hello ", "take "]
#
# list2 = ["Dear", "Sir"]
#
# Expected output:
#
# ['Hello Dear', 'Hello Sir', 'take Dear', 'take Sir']

# %%
list1 = ["Hello ", "take "]
list2 = ["Dear", "Sir"]
concate_list = [i + j for i in list1 for j in list2 ]
print(concate_list)
# Out:
# ['Hello Dear', 'Hello Sir', 'take Dear', 'take Sir']

# %% [markdown]
# 19. Given a two Python list. Write a program to iterate both lists simultaneously and display items from list1 in original order and items from list2 in reverse order.
#
# Given
#
# list1 = [10, 20, 30, 40]
# list2 = [100, 200, 300, 400]

# %%
list1 = [10, 20, 30, 40]
list2 = [100, 200, 300, 400]
for i, j in zip(list1,list2[::-1]):
    print(i,j)
# Out:
# 10 400
# 20 300
# 30 200
# 40 100

# %% [markdown]
# 20. Write a program to add item 7000 after 6000 in the following Python List
#
# Given:
#
# list1 = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]
#
# Expected output:
#
# [10, 20, [300, 400, [5000, 6000, 7000], 500], 30, 40]

# %%
list1 = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]
list1[2][2].append(7000)
print(list1)
# Out:
# [10, 20, [300, 400, [5000, 6000, 7000], 500], 30, 40]

# %% [markdown]
# 21. You have given a nested list. Write a program to extend it by adding the sublist ["h", "i", "j"] in such a way that it will look like the following list.
#
# Given List:
#
# list1 = ["a", "b", ["c", ["d", "e", ["f", "g"], "k"], "l"], "m", "n"]
#
# # sub list to add
# sub_list = ["h", "i", "j"]
#
# Expected Output:
#
# ['a', 'b', ['c', ['d', 'e', ['f', 'g', 'h', 'i', 'j'], 'k'], 'l'], 'm', 'n']

# %%
list1 = ["a", "b", ["c", ["d", "e", ["f", "g"], "k"], "l"], "m", "n"]
sub_list = ["h", "i", "j"]
list1[2][1][2].extend(sub_list)
print(list1)
# Out:
# ['a', 'b', ['c', ['d', 'e', ['f', 'g', 'h', 'i', 'j'], 'k'], 'l'], 'm', 'n']

# %% [markdown]
# 22. You have given a Python list. Write a program to find value 20 in the list, and if it is present, replace it with 200. Only update the first occurrence of an item.
#
# Given:
#
# list1 = [5, 10, 15, 20, 25, 50, 20]
#
# Expected output:
#
# [5, 10, 15, 200, 25, 50, 20]

# %%
list1 = [5, 10, 15, 20, 25, 50, 20]
index_20 = list1.index(20)
list1[index_20] = 200
print(list1)
# Out:
# [5, 10, 15, 200, 25, 50, 20]
